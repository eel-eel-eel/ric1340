# %% [markdown]
# <a href="https://colab.research.google.com/github/eel-eel-eel/ric1340/blob/main/ch04_03_BERT_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # このノートブックではBERTを利用するための環境構築をお伝えします。

# %% [markdown]
# ## ①Transformersをpipを使ってインストールしましょう。
#
# なお、異なるノートブックを利用されている場合、都度ライブラリをインストールする必要があります。

# %%
#  [ja]をつけることで、日本語の取り扱いに必要なライブラリも併せてインストールできます
# !pip install transformers[ja]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.7 MB 39.2 MB/s
# ...
#      |████████████████████████████████| 101 kB 13.2 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 51.0 MB/s
# ...
#      |████████████████████████████████| 596 kB 58.5 MB/s
# ...
#      |████████████████████████████████| 13.4 MB 18.2 MB/s
# ...
#      |████████████████████████████████| 47.4 MB 2.1 MB/s
# ...
#      |████████████████████████████████| 568 kB 55.3 MB/s
# ...
#   Created wheel for ipadic: filename=ipadic-1.0.0-py3-none-any.whl size=13556723 sha256=9268c925903fa0348e7433249b6fc7838dd5e81c47795218f5a214fcb2da6f41
#   Stored in directory: /root/.cache/pip/wheels/33/8b/99/cf0d27191876637cd3639a560f93aa982d7855ce826c94348b
# ...
#   Created wheel for unidic: filename=unidic-1.1.0-py3-none-any.whl size=7426 sha256=e312c8c7a955749fd3041dfd197a5ef74cfd7fc63db003c7ff927c039edca3ca
# ...

# %%
# 無事インストールされていることの確認のため、transformersを読み込んでみましょう
# 正常にインストールできていれば、'label'と'score'がそれぞれ表示されます
from transformers import pipeline

print(pipeline(model='cl-tohoku/bert-base-japanese-whole-word-masking',
               task='sentiment-analysis')('私は味噌汁が大好きです'))
# Out:
# ...
# Some weights of the model checkpoint at cl-tohoku/bert-base-japanese-whole-word-masking were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...
